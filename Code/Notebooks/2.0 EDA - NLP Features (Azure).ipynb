# %% [markdown]
# **LOAD LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import re
import json
import requests
from pprint import pprint
from IPython.display import HTML
import tweepy as tp
import twitter_credentials

# %% [markdown]
# # 2.0 EDA AND NLP WITH MICROSOFT AZURE
#
# This notebool will help incorporate natural language processing (NLP) features into our classification modeling. This will use an API from Microsoft’s AI Text Analytics service on Azure’s cloud computing platform (https://azure.microsoft.com/en-us/services/cognitive-services/text-analytics/)
#
# - We did some EDA on this Notebook to understand which feature would be applicable for modeling.
# - The outpout of this Notebook will be used for modeling

# %% [markdown]
# **READ FINAL MASTER FROM JSON AND PROCEED TO EDA**

# %%
#with open('tweet_master.json') as json_file:  
with open('more_final_tweet_master.json') as json_file:  
    tweet_json = json.load(json_file)

#with open('user_master.json') as json_file:  
with open('more_final_user_master.json') as json_file:  
     user_json = json.load(json_file)

# %%
tweet_df = pd.read_json(tweet_json)

user_df = pd.read_json(user_json)

print(user_df.shape)
print(tweet_df.shape)
# Out:
# (112, 14)
# (16700, 12)

# %%
# Re-index user table to be screen name since id is missing from twitter feed
user_df.set_index('screen_name',drop=False, inplace=True)

# %% [markdown]
# **MERGE COLUMNS**

# %%
# Here are verified users
bot_mask = user_df['known_bot'] == True
bots = user_df[bot_mask]
bots.shape
# Out:
# (0, 14)

# %%
# Here are known bots
verified_mask = user_df['verified'] == True
verifieds = user_df[verified_mask]
verifieds.shape
# Out:
# (107, 14)

# %%
# Here are authors of unknown 'bot or not' status
not_bot_mask = user_df['known_bot'] != True
not_verified_mask = user_df['verified'] != True
unknown_mask = np.logical_and(not_bot_mask, not_verified_mask)
unknowns = user_df[unknown_mask].copy()
unknowns.shape
# Out:
# (5, 14)

# %%
# Here are tweets for users of verified status
# NOTE:  the join
tweets_verified_users = tweet_df.join(verifieds,'user_screen_name',rsuffix='user',how='right')
tweets_verified_users.shape
# Out:
# (15950, 26)

# %%
# Here are tweets for users of unknown status
# NOTE:  the join
tweets_unknown_users = tweet_df.join(unknowns,'user_screen_name',rsuffix='user',how='right')
tweets_unknown_users.shape
# Out:
# (750, 26)

# %%
# Here are tweets for users of bot status
# NOTE:  the join
tweets_bot_users = tweet_df.join(bots,'user_screen_name',rsuffix='user',how='right')
tweets_bot_users.shape
# Out:
# (0, 26)

# %% [markdown]
# ** ENGINEER NLP FEATURES **
#
# - Will do engineering only for Tweets that have valid users, where the join with user table has succeeded.
# - We will only perform NLP for tweets in English
# - The code below uses Microsoft Azure NLP APIs to extract sentiment and key phrases from each Tweet. View more at https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/quickstarts/python#extract-key-phrases

# %%
tweets_unknown_users["TypeOfUser"] = "Unknown"
tweets_bot_users["TypeOfUser"] = "Bot"
tweets_verified_users["TypeOfUser"] = "Verified"

new_tweet_df = pd.concat([tweets_unknown_users,tweets_bot_users, tweets_verified_users], ignore_index=True)

new_tweet_df["nlp_key_phrases"] = ""
new_tweet_df["nlp_count_key_phrases"] = 0
new_tweet_df["nlp_sentiment_score"] = 0.0

print(new_tweet_df.shape)
# Out:
# (16700, 30)

# %%
print(new_tweet_df.groupby("lang").size())
# Out:
# lang
# ca         5
# cs         5
# cy         2
# da         9
# de        64
# en     14977
# es       187
# et         8
# eu         2
# fi         3
# fr        94
# hi         1
# ht        16
# hu         3
# in        21
# is         3
# it        83
# ja         3
# lt         4
# lv         2
# nl        15
# no        13
# pl         4
# pt       155
# ro         8
# ru         4
# sl         2
# sr         1
# sv         2
# tl        34
# tr         5
# uk       110
# und      852
# vi         1
# zh         2
# dtype: int64

# %%
english_filter = new_tweet_df["lang"] == "en"
uk_filter = new_tweet_df["lang"] == "uk"

mask = np.logical_or(english_filter, uk_filter)

new_tweet_df_english = new_tweet_df[mask].copy()

new_tweet_df_english.reset_index(drop=True, inplace=True)

print(new_tweet_df_english.shape, len(new_tweet_df_english))
# Out:
# (15087, 30) 15087

# %%
## THE CODE below uses Microsoft Azure APIs to detect sentiment and key phrases from each Tweet
#https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/quickstarts/python#extract-key-phrases
text_analytics_base_url = "https://eastus.api.cognitive.microsoft.com/text/analytics/v2.0/"
sentiment_api_url = text_analytics_base_url + "sentiment"
key_phrase_api_url = text_analytics_base_url + "keyPhrases"

subscription_key = "CALL EUMAR FOR GUIDANCE - 954 918 4874"

start_pos = 0 
total = len(new_tweet_df_english)

while start_pos <= total:

    try:
        index1 = start_pos
        index2 = start_pos + 1
        index3 = start_pos + 2
        index4 = start_pos + 3
        index5 = start_pos + 4
        index6 = start_pos + 5
        index7 = start_pos + 6
        index8 = start_pos + 7
        index9 = start_pos + 8
        index10 = start_pos + 9        

        print("Started Processing: Range({0}, {1})".format(index1, index10))
            
        documents = {'documents' : [
          {'id': index1, 'language': 'en', 'text': new_tweet_df_english.loc[index1].text},
          {'id': index2, 'language': 'en', 'text': new_tweet_df_english.loc[index2].text},
          {'id': index3, 'language': 'en', 'text': new_tweet_df_english.loc[index3].text},
          {'id': index4, 'language': 'en', 'text': new_tweet_df_english.loc[index4].text},
          {'id': index5, 'language': 'en', 'text': new_tweet_df_english.loc[index5].text},
          {'id': index6, 'language': 'en', 'text': new_tweet_df_english.loc[index6].text},
          {'id': index7, 'language': 'en', 'text': new_tweet_df_english.loc[index7].text},
          {'id': index8, 'language': 'en', 'text': new_tweet_df_english.loc[index8].text},
          {'id': index9, 'language': 'en', 'text': new_tweet_df_english.loc[index9].text},
          {'id': index10, 'language': 'en', 'text': new_tweet_df_english.loc[index10].text}
        ]}


        headers   = {"Ocp-Apim-Subscription-Key": subscription_key}
        response_key_phrase  = requests.post(key_phrase_api_url, headers=headers, json=documents)
        key_phrases = response_key_phrase.json()

        response_sentiment  = requests.post(sentiment_api_url, headers=headers, json=documents)
        sentiment = response_sentiment.json()


        for document in key_phrases["documents"]:
            id_doc = int(document["id"])
            num_phrases = len(document["keyPhrases"])
            phrases_doc = ",".join(document["keyPhrases"])

            new_tweet_df_english.loc[id_doc, "nlp_key_phrases"] = phrases_doc
            new_tweet_df_english.loc[id_doc, "nlp_count_key_phrases"] = num_phrases    

            #print(id_doc,new_tweet_df.loc[id_doc, "nlp_key_phrases"],  new_tweet_df.loc[id_doc, "nlp_count_key_phrases"])

        for document in sentiment["documents"]:
            id_doc = int(document["id"])
            score = document["score"]

            new_tweet_df_english.loc[id_doc, "nlp_sentiment_score"] = float(score)

            #print (id_doc, new_tweet_df.loc[id_doc, "nlp_sentiment_score"])

        print("Finished Processing: Range({0}, {1})".format(index1, index10))
        
        start_pos = start_pos + 10
    except Exception as e:
        print(f'SOME ERROR OCCURRED...PASSING!!!')
        print(e)
        start_pos = start_pos + 10
        pass
# Out:
# Started Processing: Range(0, 9)
# Finished Processing: Range(0, 9)
# Started Processing: Range(10, 19)
# Finished Processing: Range(10, 19)
# Started Processing: Range(20, 29)
# Finished Processing: Range(20, 29)
# Started Processing: Range(30, 39)
# Finished Processing: Range(30, 39)
# Started Processing: Range(40, 49)
# Finished Processing: Range(40, 49)
# Started Processing: Range(50, 59)
# Finished Processing: Range(50, 59)
# Started Processing: Range(60, 69)
# Finished Processing: Range(60, 69)
# Started Processing: Range(70, 79)
# Finished Processing: Range(70, 79)
# Started Processing: Range(80, 89)
# Finished Processing: Range(80, 89)
# Started Processing: Range(90, 99)
# Finished Processing: Range(90, 99)
# Started Processing: Range(100, 109)
# Finished Processing: Range(100, 109)
# Started Processing: Range(110, 119)
# Finished Processing: Range(110, 119)
# Started Processing: Range(120, 129)
# Finished Processing: Range(120, 129)
# Started Processing: Range(130, 139)
# Finished Processing: Range(130, 139)
# Started Processing: Range(140, 149)
# Finished Processing: Range(140, 149)
# Started Processing: Range(150, 159)
# Finished Processing: Range(150, 159)
# Started Processing: Range(160, 169)
# Finished Processing: Range(160, 169)
# Started Processing: Range(170, 179)
# Finished Processing: Range(170, 179)
# Started Processing: Range(180, 189)
# Finished Processing: Range(180, 189)
# Started Processing: Range(190, 199)
# Finished Processing: Range(190, 199)
# Started Processing: Range(200, 209)
# Finished Processing: Range(200, 209)
# Started Processing: Range(210, 219)
# Finished Processing: Range(210, 219)
# Started Processing: Range(220, 229)
# Finished Processing: Range(220, 229)
# Started Processing: Range(230, 239)
# Finished Processing: Range(230, 239)
# Started Processing: Range(240, 249)
# Finished Processing: Range(240, 249)
# Started Processing: Range(250, 259)
# Finished Processing: Range(250, 259)
# Started Processing: Range(260, 269)
# Finished Processing: Range(260, 269)
# Started Processing: Range(270, 279)
# Finished Processing: Range(270, 279)
# Started Processing: Range(280, 289)
# Finished Processing: Range(280, 289)
# Started Processing: Range(290, 299)
# Finished Processing: Range(290, 299)
# Started Processing: Range(300, 309)
# Finished Processing: Range(300, 309)
# Started Processing: Range(310, 319)
# Finished Processing: Range(310, 319)
# Started Processing: Range(320, 329)
# Finished Processing: Range(320, 329)
# Started Processing: Range(330, 339)
# Finished Processing: Range(330, 339)
# Started Processing: Range(340, 349)
# Finished Processing: Range(340, 349)
# Started Processing: Range(350, 359)
# Finished Processing: Range(350, 359)
# Started Processing: Range(360, 369)
# Finished Processing: Range(360, 369)
# Started Processing: Range(370, 379)
# Finished Processing: Range(370, 379)
# Started Processing: Range(380, 389)
# Finished Processing: Range(380, 389)
# Started Processing: Range(390, 399)
# Finished Processing: Range(390, 399)
# Started Processing: Range(400, 409)
# Finished Processing: Range(400, 409)
# Started Processing: Range(410, 419)
# Finished Processing: Range(410, 419)
# Started Processing: Range(420, 429)
# Finished Processing: Range(420, 429)
# Started Processing: Range(430, 439)
# Finished Processing: Range(430, 439)
# Started Processing: Range(440, 449)
# Finished Processing: Range(440, 449)
# Started Processing: Range(450, 459)
# Finished Processing: Range(450, 459)
# Started Processing: Range(460, 469)
# Finished Processing: Range(460, 469)
# Started Processing: Range(470, 479)
# Finished Processing: Range(470, 479)
# Started Processing: Range(480, 489)
# Finished Processing: Range(480, 489)
# Started Processing: Range(490, 499)
# Finished Processing: Range(490, 499)
# Started Processing: Range(500, 509)
# Finished Processing: Range(500, 509)
# Started Processing: Range(510, 519)
# Finished Processing: Range(510, 519)
# Started Processing: Range(520, 529)
# Finished Processing: Range(520, 529)
# Started Processing: Range(530, 539)
# Finished Processing: Range(530, 539)
# Started Processing: Range(540, 549)
# Finished Processing: Range(540, 549)
# Started Processing: Range(550, 559)
# Finished Processing: Range(550, 559)
# Started Processing: Range(560, 569)
# Finished Processing: Range(560, 569)
# Started Processing: Range(570, 579)
# Finished Processing: Range(570, 579)
# Started Processing: Range(580, 589)
# Finished Processing: Range(580, 589)
# Started Processing: Range(590, 599)
# Finished Processing: Range(590, 599)
# Started Processing: Range(600, 609)
# Finished Processing: Range(600, 609)
# Started Processing: Range(610, 619)
# Finished Processing: Range(610, 619)
# Started Processing: Range(620, 629)
# Finished Processing: Range(620, 629)
# Started Processing: Range(630, 639)
# Finished Processing: Range(630, 639)
# Started Processing: Range(640, 649)
# Finished Processing: Range(640, 649)
# Started Processing: Range(650, 659)
# Finished Processing: Range(650, 659)
# Started Processing: Range(660, 669)
# Finished Processing: Range(660, 669)
# Started Processing: Range(670, 679)
# Finished Processing: Range(670, 679)
# Started Processing: Range(680, 689)
# Finished Processing: Range(680, 689)
# Started Processing: Range(690, 699)
# Finished Processing: Range(690, 699)
# Started Processing: Range(700, 709)
# Finished Processing: Range(700, 709)
# Started Processing: Range(710, 719)
# Finished Processing: Range(710, 719)
# Started Processing: Range(720, 729)
# Finished Processing: Range(720, 729)
# Started Processing: Range(730, 739)
# Finished Processing: Range(730, 739)
# Started Processing: Range(740, 749)
# Finished Processing: Range(740, 749)
# Started Processing: Range(750, 759)
# Finished Processing: Range(750, 759)
# Started Processing: Range(760, 769)
# Finished Processing: Range(760, 769)
# Started Processing: Range(770, 779)
# Finished Processing: Range(770, 779)
# Started Processing: Range(780, 789)
# Finished Processing: Range(780, 789)
# Started Processing: Range(790, 799)
# Finished Processing: Range(790, 799)
# Started Processing: Range(800, 809)
# Finished Processing: Range(800, 809)
# Started Processing: Range(810, 819)
# Finished Processing: Range(810, 819)
# Started Processing: Range(820, 829)
# Finished Processing: Range(820, 829)
# Started Processing: Range(830, 839)
# Finished Processing: Range(830, 839)
# Started Processing: Range(840, 849)
# Finished Processing: Range(840, 849)
# Started Processing: Range(850, 859)
# Finished Processing: Range(850, 859)
# Started Processing: Range(860, 869)
# Finished Processing: Range(860, 869)
# Started Processing: Range(870, 879)
# Finished Processing: Range(870, 879)
# Started Processing: Range(880, 889)
# Finished Processing: Range(880, 889)
# Started Processing: Range(890, 899)
# Finished Processing: Range(890, 899)
# Started Processing: Range(900, 909)
# Finished Processing: Range(900, 909)
# Started Processing: Range(910, 919)
# Finished Processing: Range(910, 919)
# Started Processing: Range(920, 929)
# Finished Processing: Range(920, 929)
# Started Processing: Range(930, 939)
# Finished Processing: Range(930, 939)
# Started Processing: Range(940, 949)
# Finished Processing: Range(940, 949)
# Started Processing: Range(950, 959)
# Finished Processing: Range(950, 959)
# Started Processing: Range(960, 969)
# Finished Processing: Range(960, 969)
# Started Processing: Range(970, 979)
# Finished Processing: Range(970, 979)
# Started Processing: Range(980, 989)
# Finished Processing: Range(980, 989)
# Started Processing: Range(990, 999)
# Finished Processing: Range(990, 999)
# Started Processing: Range(1000, 1009)
# Finished Processing: Range(1000, 1009)
# Started Processing: Range(1010, 1019)
# Finished Processing: Range(1010, 1019)
# Started Processing: Range(1020, 1029)
# Finished Processing: Range(1020, 1029)
# Started Processing: Range(1030, 1039)
# Finished Processing: Range(1030, 1039)
# Started Processing: Range(1040, 1049)
# Finished Processing: Range(1040, 1049)
# Started Processing: Range(1050, 1059)
# Finished Processing: Range(1050, 1059)
# Started Processing: Range(1060, 1069)
# Finished Processing: Range(1060, 1069)
# Started Processing: Range(1070, 1079)
# Finished Processing: Range(1070, 1079)
# Started Processing: Range(1080, 1089)
# Finished Processing: Range(1080, 1089)
# Started Processing: Range(1090, 1099)
# Finished Processing: Range(1090, 1099)
# Started Processing: Range(1100, 1109)
# Finished Processing: Range(1100, 1109)
# Started Processing: Range(1110, 1119)
# Finished Processing: Range(1110, 1119)
# Started Processing: Range(1120, 1129)
# Finished Processing: Range(1120, 1129)
# Started Processing: Range(1130, 1139)
# Finished Processing: Range(1130, 1139)
# Started Processing: Range(1140, 1149)
# Finished Processing: Range(1140, 1149)
# Started Processing: Range(1150, 1159)
# Finished Processing: Range(1150, 1159)
# Started Processing: Range(1160, 1169)
# Finished Processing: Range(1160, 1169)
# Started Processing: Range(1170, 1179)
# Finished Processing: Range(1170, 1179)
# Started Processing: Range(1180, 1189)
# Finished Processing: Range(1180, 1189)
# Started Processing: Range(1190, 1199)
# Finished Processing: Range(1190, 1199)
# Started Processing: Range(1200, 1209)
# Finished Processing: Range(1200, 1209)
# Started Processing: Range(1210, 1219)
# Finished Processing: Range(1210, 1219)
# Started Processing: Range(1220, 1229)
# Finished Processing: Range(1220, 1229)
# Started Processing: Range(1230, 1239)
# Finished Processing: Range(1230, 1239)
# Started Processing: Range(1240, 1249)
# Finished Processing: Range(1240, 1249)
# Started Processing: Range(1250, 1259)
# Finished Processing: Range(1250, 1259)
# Started Processing: Range(1260, 1269)
# Finished Processing: Range(1260, 1269)
# Started Processing: Range(1270, 1279)
# Finished Processing: Range(1270, 1279)
# Started Processing: Range(1280, 1289)
# Finished Processing: Range(1280, 1289)
# Started Processing: Range(1290, 1299)
# Finished Processing: Range(1290, 1299)
# Started Processing: Range(1300, 1309)
# Finished Processing: Range(1300, 1309)
# Started Processing: Range(1310, 1319)
# Finished Processing: Range(1310, 1319)
# Started Processing: Range(1320, 1329)
# Finished Processing: Range(1320, 1329)
# Started Processing: Range(1330, 1339)
# Finished Processing: Range(1330, 1339)
# Started Processing: Range(1340, 1349)
# Finished Processing: Range(1340, 1349)
# Started Processing: Range(1350, 1359)
# Finished Processing: Range(1350, 1359)
# Started Processing: Range(1360, 1369)
# Finished Processing: Range(1360, 1369)
# Started Processing: Range(1370, 1379)
# Finished Processing: Range(1370, 1379)
# Started Processing: Range(1380, 1389)
# Finished Processing: Range(1380, 1389)
# Started Processing: Range(1390, 1399)
# Finished Processing: Range(1390, 1399)
# Started Processing: Range(1400, 1409)
# Finished Processing: Range(1400, 1409)
# Started Processing: Range(1410, 1419)
# Finished Processing: Range(1410, 1419)
# Started Processing: Range(1420, 1429)
# Finished Processing: Range(1420, 1429)
# Started Processing: Range(1430, 1439)
# Finished Processing: Range(1430, 1439)
# Started Processing: Range(1440, 1449)
# Finished Processing: Range(1440, 1449)
# Started Processing: Range(1450, 1459)
# Finished Processing: Range(1450, 1459)
# Started Processing: Range(1460, 1469)
# Finished Processing: Range(1460, 1469)
# Started Processing: Range(1470, 1479)
# Finished Processing: Range(1470, 1479)
# Started Processing: Range(1480, 1489)
# Finished Processing: Range(1480, 1489)
# Started Processing: Range(1490, 1499)
# Finished Processing: Range(1490, 1499)
# Started Processing: Range(1500, 1509)
# Finished Processing: Range(1500, 1509)
# Started Processing: Range(1510, 1519)
# Finished Processing: Range(1510, 1519)
# Started Processing: Range(1520, 1529)
# Finished Processing: Range(1520, 1529)
# Started Processing: Range(1530, 1539)
# Finished Processing: Range(1530, 1539)
# Started Processing: Range(1540, 1549)
# Finished Processing: Range(1540, 1549)
# Started Processing: Range(1550, 1559)
# Finished Processing: Range(1550, 1559)
# Started Processing: Range(1560, 1569)
# Finished Processing: Range(1560, 1569)
# Started Processing: Range(1570, 1579)
# Finished Processing: Range(1570, 1579)
# Started Processing: Range(1580, 1589)
# Finished Processing: Range(1580, 1589)
# Started Processing: Range(1590, 1599)
# Finished Processing: Range(1590, 1599)
# Started Processing: Range(1600, 1609)
# Finished Processing: Range(1600, 1609)
# Started Processing: Range(1610, 1619)
# Finished Processing: Range(1610, 1619)
# Started Processing: Range(1620, 1629)
# Finished Processing: Range(1620, 1629)
# Started Processing: Range(1630, 1639)
# Finished Processing: Range(1630, 1639)
# Started Processing: Range(1640, 1649)
# Finished Processing: Range(1640, 1649)
# Started Processing: Range(1650, 1659)
# Finished Processing: Range(1650, 1659)
# Started Processing: Range(1660, 1669)
# Finished Processing: Range(1660, 1669)
# Started Processing: Range(1670, 1679)
# Finished Processing: Range(1670, 1679)
# Started Processing: Range(1680, 1689)
# Finished Processing: Range(1680, 1689)
# Started Processing: Range(1690, 1699)
# Finished Processing: Range(1690, 1699)
# Started Processing: Range(1700, 1709)
# Finished Processing: Range(1700, 1709)
# Started Processing: Range(1710, 1719)
# Finished Processing: Range(1710, 1719)
# Started Processing: Range(1720, 1729)
# Finished Processing: Range(1720, 1729)
# Started Processing: Range(1730, 1739)
# Finished Processing: Range(1730, 1739)
# Started Processing: Range(1740, 1749)
# Finished Processing: Range(1740, 1749)
# Started Processing: Range(1750, 1759)
# Finished Processing: Range(1750, 1759)
# Started Processing: Range(1760, 1769)
# Finished Processing: Range(1760, 1769)
# Started Processing: Range(1770, 1779)
# Finished Processing: Range(1770, 1779)
# Started Processing: Range(1780, 1789)
# Finished Processing: Range(1780, 1789)
# Started Processing: Range(1790, 1799)
# Finished Processing: Range(1790, 1799)
# Started Processing: Range(1800, 1809)
# Finished Processing: Range(1800, 1809)
# Started Processing: Range(1810, 1819)
# Finished Processing: Range(1810, 1819)
# Started Processing: Range(1820, 1829)
# Finished Processing: Range(1820, 1829)
# Started Processing: Range(1830, 1839)
# Finished Processing: Range(1830, 1839)
# Started Processing: Range(1840, 1849)
# Finished Processing: Range(1840, 1849)
# Started Processing: Range(1850, 1859)
# Finished Processing: Range(1850, 1859)
# Started Processing: Range(1860, 1869)
# Finished Processing: Range(1860, 1869)
# Started Processing: Range(1870, 1879)
# Finished Processing: Range(1870, 1879)
# Started Processing: Range(1880, 1889)
# Finished Processing: Range(1880, 1889)
# Started Processing: Range(1890, 1899)
# Finished Processing: Range(1890, 1899)
# Started Processing: Range(1900, 1909)
# Finished Processing: Range(1900, 1909)
# Started Processing: Range(1910, 1919)
# Finished Processing: Range(1910, 1919)
# Started Processing: Range(1920, 1929)
# Finished Processing: Range(1920, 1929)
# Started Processing: Range(1930, 1939)
# Finished Processing: Range(1930, 1939)
# Started Processing: Range(1940, 1949)
# Finished Processing: Range(1940, 1949)
# Started Processing: Range(1950, 1959)
# Finished Processing: Range(1950, 1959)
# Started Processing: Range(1960, 1969)
# Finished Processing: Range(1960, 1969)
# Started Processing: Range(1970, 1979)
# Finished Processing: Range(1970, 1979)
# Started Processing: Range(1980, 1989)
# Finished Processing: Range(1980, 1989)
# Started Processing: Range(1990, 1999)
# Finished Processing: Range(1990, 1999)
# Started Processing: Range(2000, 2009)
# Finished Processing: Range(2000, 2009)
# Started Processing: Range(2010, 2019)
# Finished Processing: Range(2010, 2019)
# Started Processing: Range(2020, 2029)
# Finished Processing: Range(2020, 2029)
# Started Processing: Range(2030, 2039)
# Finished Processing: Range(2030, 2039)
# Started Processing: Range(2040, 2049)
# Finished Processing: Range(2040, 2049)
# Started Processing: Range(2050, 2059)
# Finished Processing: Range(2050, 2059)
# Started Processing: Range(2060, 2069)
# Finished Processing: Range(2060, 2069)
# Started Processing: Range(2070, 2079)
# Finished Processing: Range(2070, 2079)
# Started Processing: Range(2080, 2089)
# Finished Processing: Range(2080, 2089)
# Started Processing: Range(2090, 2099)
# Finished Processing: Range(2090, 2099)
# Started Processing: Range(2100, 2109)
# Finished Processing: Range(2100, 2109)
# Started Processing: Range(2110, 2119)
# Finished Processing: Range(2110, 2119)
# Started Processing: Range(2120, 2129)
# Finished Processing: Range(2120, 2129)
# Started Processing: Range(2130, 2139)
# Finished Processing: Range(2130, 2139)
# Started Processing: Range(2140, 2149)
# Finished Processing: Range(2140, 2149)
# Started Processing: Range(2150, 2159)
# Finished Processing: Range(2150, 2159)
# Started Processing: Range(2160, 2169)
# Finished Processing: Range(2160, 2169)
# Started Processing: Range(2170, 2179)
# Finished Processing: Range(2170, 2179)
# Started Processing: Range(2180, 2189)
# Finished Processing: Range(2180, 2189)
# Started Processing: Range(2190, 2199)
# Finished Processing: Range(2190, 2199)
# Started Processing: Range(2200, 2209)
# Finished Processing: Range(2200, 2209)
# Started Processing: Range(2210, 2219)
# Finished Processing: Range(2210, 2219)
# Started Processing: Range(2220, 2229)
# Finished Processing: Range(2220, 2229)
# Started Processing: Range(2230, 2239)
# Finished Processing: Range(2230, 2239)
# Started Processing: Range(2240, 2249)
# Finished Processing: Range(2240, 2249)
# Started Processing: Range(2250, 2259)
# Finished Processing: Range(2250, 2259)
# Started Processing: Range(2260, 2269)
# Finished Processing: Range(2260, 2269)
# Started Processing: Range(2270, 2279)
# Finished Processing: Range(2270, 2279)
# Started Processing: Range(2280, 2289)
# Finished Processing: Range(2280, 2289)
# Started Processing: Range(2290, 2299)
# Finished Processing: Range(2290, 2299)
# Started Processing: Range(2300, 2309)
# Finished Processing: Range(2300, 2309)
# Started Processing: Range(2310, 2319)
# Finished Processing: Range(2310, 2319)
# Started Processing: Range(2320, 2329)
# Finished Processing: Range(2320, 2329)
# Started Processing: Range(2330, 2339)
# Finished Processing: Range(2330, 2339)
# Started Processing: Range(2340, 2349)
# Finished Processing: Range(2340, 2349)
# Started Processing: Range(2350, 2359)
# Finished Processing: Range(2350, 2359)
# Started Processing: Range(2360, 2369)
# Finished Processing: Range(2360, 2369)
# Started Processing: Range(2370, 2379)
# Finished Processing: Range(2370, 2379)
# Started Processing: Range(2380, 2389)
# Finished Processing: Range(2380, 2389)
# Started Processing: Range(2390, 2399)
# Finished Processing: Range(2390, 2399)
# Started Processing: Range(2400, 2409)
# Finished Processing: Range(2400, 2409)
# Started Processing: Range(2410, 2419)
# Finished Processing: Range(2410, 2419)
# Started Processing: Range(2420, 2429)
# Finished Processing: Range(2420, 2429)
# Started Processing: Range(2430, 2439)
# Finished Processing: Range(2430, 2439)
# Started Processing: Range(2440, 2449)
# Finished Processing: Range(2440, 2449)
# Started Processing: Range(2450, 2459)
# Finished Processing: Range(2450, 2459)
# Started Processing: Range(2460, 2469)
# Finished Processing: Range(2460, 2469)
# Started Processing: Range(2470, 2479)
# Finished Processing: Range(2470, 2479)
# Started Processing: Range(2480, 2489)
# Finished Processing: Range(2480, 2489)
# Started Processing: Range(2490, 2499)
# Finished Processing: Range(2490, 2499)
# Started Processing: Range(2500, 2509)
# Finished Processing: Range(2500, 2509)
# Started Processing: Range(2510, 2519)
# Finished Processing: Range(2510, 2519)
# Started Processing: Range(2520, 2529)
# Finished Processing: Range(2520, 2529)
# Started Processing: Range(2530, 2539)
# Finished Processing: Range(2530, 2539)
# Started Processing: Range(2540, 2549)
# Finished Processing: Range(2540, 2549)
# Started Processing: Range(2550, 2559)
# Finished Processing: Range(2550, 2559)
# Started Processing: Range(2560, 2569)
# Finished Processing: Range(2560, 2569)
# Started Processing: Range(2570, 2579)
# Finished Processing: Range(2570, 2579)
# Started Processing: Range(2580, 2589)
# Finished Processing: Range(2580, 2589)
# Started Processing: Range(2590, 2599)
# Finished Processing: Range(2590, 2599)
# Started Processing: Range(2600, 2609)
# Finished Processing: Range(2600, 2609)
# Started Processing: Range(2610, 2619)
# Finished Processing: Range(2610, 2619)
# Started Processing: Range(2620, 2629)
# Finished Processing: Range(2620, 2629)
# Started Processing: Range(2630, 2639)
# Finished Processing: Range(2630, 2639)
# Started Processing: Range(2640, 2649)
# Finished Processing: Range(2640, 2649)
# Started Processing: Range(2650, 2659)
# Finished Processing: Range(2650, 2659)
# Started Processing: Range(2660, 2669)
# Finished Processing: Range(2660, 2669)
# Started Processing: Range(2670, 2679)
# Finished Processing: Range(2670, 2679)
# Started Processing: Range(2680, 2689)
# Finished Processing: Range(2680, 2689)
# Started Processing: Range(2690, 2699)
# Finished Processing: Range(2690, 2699)
# Started Processing: Range(2700, 2709)
# Finished Processing: Range(2700, 2709)
# Started Processing: Range(2710, 2719)
# Finished Processing: Range(2710, 2719)
# Started Processing: Range(2720, 2729)
# Finished Processing: Range(2720, 2729)
# Started Processing: Range(2730, 2739)
# Finished Processing: Range(2730, 2739)
# Started Processing: Range(2740, 2749)
# Finished Processing: Range(2740, 2749)
# Started Processing: Range(2750, 2759)
# Finished Processing: Range(2750, 2759)
# Started Processing: Range(2760, 2769)
# Finished Processing: Range(2760, 2769)
# Started Processing: Range(2770, 2779)
# Finished Processing: Range(2770, 2779)
# Started Processing: Range(2780, 2789)
# Finished Processing: Range(2780, 2789)
# Started Processing: Range(2790, 2799)
# Finished Processing: Range(2790, 2799)
# Started Processing: Range(2800, 2809)
# Finished Processing: Range(2800, 2809)
# Started Processing: Range(2810, 2819)
# Finished Processing: Range(2810, 2819)
# Started Processing: Range(2820, 2829)
# Finished Processing: Range(2820, 2829)
# Started Processing: Range(2830, 2839)
# Finished Processing: Range(2830, 2839)
# Started Processing: Range(2840, 2849)
# Finished Processing: Range(2840, 2849)
# Started Processing: Range(2850, 2859)
# Finished Processing: Range(2850, 2859)
# Started Processing: Range(2860, 2869)
# Finished Processing: Range(2860, 2869)
# Started Processing: Range(2870, 2879)
# Finished Processing: Range(2870, 2879)
# Started Processing: Range(2880, 2889)
# Finished Processing: Range(2880, 2889)
# Started Processing: Range(2890, 2899)
# Finished Processing: Range(2890, 2899)
# Started Processing: Range(2900, 2909)
# Finished Processing: Range(2900, 2909)
# Started Processing: Range(2910, 2919)
# Finished Processing: Range(2910, 2919)
# Started Processing: Range(2920, 2929)
# Finished Processing: Range(2920, 2929)
# Started Processing: Range(2930, 2939)
# Finished Processing: Range(2930, 2939)
# Started Processing: Range(2940, 2949)
# Finished Processing: Range(2940, 2949)
# Started Processing: Range(2950, 2959)
# Finished Processing: Range(2950, 2959)
# Started Processing: Range(2960, 2969)
# Finished Processing: Range(2960, 2969)
# Started Processing: Range(2970, 2979)
# Finished Processing: Range(2970, 2979)
# Started Processing: Range(2980, 2989)
# Finished Processing: Range(2980, 2989)
# Started Processing: Range(2990, 2999)
# Finished Processing: Range(2990, 2999)
# Started Processing: Range(3000, 3009)
# Finished Processing: Range(3000, 3009)
# Started Processing: Range(3010, 3019)
# Finished Processing: Range(3010, 3019)
# Started Processing: Range(3020, 3029)
# Finished Processing: Range(3020, 3029)
# Started Processing: Range(3030, 3039)
# Finished Processing: Range(3030, 3039)
# Started Processing: Range(3040, 3049)
# Finished Processing: Range(3040, 3049)
# Started Processing: Range(3050, 3059)
# Finished Processing: Range(3050, 3059)
# Started Processing: Range(3060, 3069)
# Finished Processing: Range(3060, 3069)
# Started Processing: Range(3070, 3079)
# Finished Processing: Range(3070, 3079)
# Started Processing: Range(3080, 3089)
# Finished Processing: Range(3080, 3089)
# Started Processing: Range(3090, 3099)
# Finished Processing: Range(3090, 3099)
# Started Processing: Range(3100, 3109)
# Finished Processing: Range(3100, 3109)
# Started Processing: Range(3110, 3119)
# Finished Processing: Range(3110, 3119)
# Started Processing: Range(3120, 3129)
# Finished Processing: Range(3120, 3129)
# Started Processing: Range(3130, 3139)
# Finished Processing: Range(3130, 3139)
# Started Processing: Range(3140, 3149)
# Finished Processing: Range(3140, 3149)
# Started Processing: Range(3150, 3159)
# Finished Processing: Range(3150, 3159)
# Started Processing: Range(3160, 3169)
# Finished Processing: Range(3160, 3169)
# Started Processing: Range(3170, 3179)
# Finished Processing: Range(3170, 3179)
# Started Processing: Range(3180, 3189)
# Finished Processing: Range(3180, 3189)
# Started Processing: Range(3190, 3199)
# Finished Processing: Range(3190, 3199)
# Started Processing: Range(3200, 3209)
# Finished Processing: Range(3200, 3209)
# Started Processing: Range(3210, 3219)
# Finished Processing: Range(3210, 3219)
# Started Processing: Range(3220, 3229)
# Finished Processing: Range(3220, 3229)
# Started Processing: Range(3230, 3239)
# Finished Processing: Range(3230, 3239)
# Started Processing: Range(3240, 3249)
# Finished Processing: Range(3240, 3249)
# Started Processing: Range(3250, 3259)
# Finished Processing: Range(3250, 3259)
# Started Processing: Range(3260, 3269)
# Finished Processing: Range(3260, 3269)
# Started Processing: Range(3270, 3279)
# Finished Processing: Range(3270, 3279)
# Started Processing: Range(3280, 3289)
# Finished Processing: Range(3280, 3289)
# Started Processing: Range(3290, 3299)
# Finished Processing: Range(3290, 3299)
# Started Processing: Range(3300, 3309)
# Finished Processing: Range(3300, 3309)
# Started Processing: Range(3310, 3319)
# Finished Processing: Range(3310, 3319)
# Started Processing: Range(3320, 3329)
# Finished Processing: Range(3320, 3329)
# Started Processing: Range(3330, 3339)
# Finished Processing: Range(3330, 3339)
# Started Processing: Range(3340, 3349)
# Finished Processing: Range(3340, 3349)
# Started Processing: Range(3350, 3359)
# Finished Processing: Range(3350, 3359)
# Started Processing: Range(3360, 3369)
# Finished Processing: Range(3360, 3369)
# Started Processing: Range(3370, 3379)
# Finished Processing: Range(3370, 3379)
# Started Processing: Range(3380, 3389)
# Finished Processing: Range(3380, 3389)
# Started Processing: Range(3390, 3399)
# Finished Processing: Range(3390, 3399)
# Started Processing: Range(3400, 3409)
# Finished Processing: Range(3400, 3409)
# Started Processing: Range(3410, 3419)
# Finished Processing: Range(3410, 3419)
# Started Processing: Range(3420, 3429)
# Finished Processing: Range(3420, 3429)
# Started Processing: Range(3430, 3439)
# Finished Processing: Range(3430, 3439)
# Started Processing: Range(3440, 3449)
# Finished Processing: Range(3440, 3449)
# Started Processing: Range(3450, 3459)
# Finished Processing: Range(3450, 3459)
# Started Processing: Range(3460, 3469)
# Finished Processing: Range(3460, 3469)
# Started Processing: Range(3470, 3479)
# Finished Processing: Range(3470, 3479)
# Started Processing: Range(3480, 3489)
# Finished Processing: Range(3480, 3489)
# Started Processing: Range(3490, 3499)
# Finished Processing: Range(3490, 3499)
# Started Processing: Range(3500, 3509)
# Finished Processing: Range(3500, 3509)
# Started Processing: Range(3510, 3519)
# Finished Processing: Range(3510, 3519)
# Started Processing: Range(3520, 3529)
# Finished Processing: Range(3520, 3529)
# Started Processing: Range(3530, 3539)
# Finished Processing: Range(3530, 3539)
# Started Processing: Range(3540, 3549)
# Finished Processing: Range(3540, 3549)
# Started Processing: Range(3550, 3559)
# Finished Processing: Range(3550, 3559)
# Started Processing: Range(3560, 3569)
# Finished Processing: Range(3560, 3569)
# Started Processing: Range(3570, 3579)
# Finished Processing: Range(3570, 3579)
# Started Processing: Range(3580, 3589)
# Finished Processing: Range(3580, 3589)
# Started Processing: Range(3590, 3599)
# Finished Processing: Range(3590, 3599)
# Started Processing: Range(3600, 3609)
# Finished Processing: Range(3600, 3609)
# Started Processing: Range(3610, 3619)
# Finished Processing: Range(3610, 3619)
# Started Processing: Range(3620, 3629)
# Finished Processing: Range(3620, 3629)
# Started Processing: Range(3630, 3639)
# Finished Processing: Range(3630, 3639)
# Started Processing: Range(3640, 3649)
# Finished Processing: Range(3640, 3649)
# Started Processing: Range(3650, 3659)
# Finished Processing: Range(3650, 3659)
# Started Processing: Range(3660, 3669)
# Finished Processing: Range(3660, 3669)
# Started Processing: Range(3670, 3679)
# Finished Processing: Range(3670, 3679)
# Started Processing: Range(3680, 3689)
# Finished Processing: Range(3680, 3689)
# Started Processing: Range(3690, 3699)
# Finished Processing: Range(3690, 3699)
# Started Processing: Range(3700, 3709)
# Finished Processing: Range(3700, 3709)
# Started Processing: Range(3710, 3719)
# Finished Processing: Range(3710, 3719)
# Started Processing: Range(3720, 3729)
# Finished Processing: Range(3720, 3729)
# Started Processing: Range(3730, 3739)
# Finished Processing: Range(3730, 3739)
# Started Processing: Range(3740, 3749)
# Finished Processing: Range(3740, 3749)
# Started Processing: Range(3750, 3759)
# Finished Processing: Range(3750, 3759)
# Started Processing: Range(3760, 3769)
# Finished Processing: Range(3760, 3769)
# Started Processing: Range(3770, 3779)
# Finished Processing: Range(3770, 3779)
# Started Processing: Range(3780, 3789)
# Finished Processing: Range(3780, 3789)
# Started Processing: Range(3790, 3799)
# Finished Processing: Range(3790, 3799)
# Started Processing: Range(3800, 3809)
# Finished Processing: Range(3800, 3809)
# Started Processing: Range(3810, 3819)
# Finished Processing: Range(3810, 3819)
# Started Processing: Range(3820, 3829)
# Finished Processing: Range(3820, 3829)
# Started Processing: Range(3830, 3839)
# Finished Processing: Range(3830, 3839)
# Started Processing: Range(3840, 3849)
# Finished Processing: Range(3840, 3849)
# Started Processing: Range(3850, 3859)
# Finished Processing: Range(3850, 3859)
# Started Processing: Range(3860, 3869)
# Finished Processing: Range(3860, 3869)
# Started Processing: Range(3870, 3879)
# Finished Processing: Range(3870, 3879)
# Started Processing: Range(3880, 3889)
# Finished Processing: Range(3880, 3889)
# Started Processing: Range(3890, 3899)
# Finished Processing: Range(3890, 3899)
# Started Processing: Range(3900, 3909)
# Finished Processing: Range(3900, 3909)
# Started Processing: Range(3910, 3919)
# Finished Processing: Range(3910, 3919)
# Started Processing: Range(3920, 3929)
# Finished Processing: Range(3920, 3929)
# Started Processing: Range(3930, 3939)
# Finished Processing: Range(3930, 3939)
# Started Processing: Range(3940, 3949)
# Finished Processing: Range(3940, 3949)
# Started Processing: Range(3950, 3959)
# Finished Processing: Range(3950, 3959)
# Started Processing: Range(3960, 3969)
# Finished Processing: Range(3960, 3969)
# Started Processing: Range(3970, 3979)
# Finished Processing: Range(3970, 3979)
# Started Processing: Range(3980, 3989)
# Finished Processing: Range(3980, 3989)
# Started Processing: Range(3990, 3999)
# Finished Processing: Range(3990, 3999)
# Started Processing: Range(4000, 4009)
# Finished Processing: Range(4000, 4009)
# Started Processing: Range(4010, 4019)
# Finished Processing: Range(4010, 4019)
# Started Processing: Range(4020, 4029)
# Finished Processing: Range(4020, 4029)
# Started Processing: Range(4030, 4039)
# Finished Processing: Range(4030, 4039)
# Started Processing: Range(4040, 4049)
# Finished Processing: Range(4040, 4049)
# Started Processing: Range(4050, 4059)
# Finished Processing: Range(4050, 4059)
# Started Processing: Range(4060, 4069)
# Finished Processing: Range(4060, 4069)
# Started Processing: Range(4070, 4079)
# Finished Processing: Range(4070, 4079)
# Started Processing: Range(4080, 4089)
# Finished Processing: Range(4080, 4089)
# Started Processing: Range(4090, 4099)
# Finished Processing: Range(4090, 4099)
# Started Processing: Range(4100, 4109)
# Finished Processing: Range(4100, 4109)
# Started Processing: Range(4110, 4119)
# Finished Processing: Range(4110, 4119)
# Started Processing: Range(4120, 4129)
# Finished Processing: Range(4120, 4129)
# Started Processing: Range(4130, 4139)
# Finished Processing: Range(4130, 4139)
# Started Processing: Range(4140, 4149)
# Finished Processing: Range(4140, 4149)
# Started Processing: Range(4150, 4159)
# Finished Processing: Range(4150, 4159)
# Started Processing: Range(4160, 4169)
# Finished Processing: Range(4160, 4169)
# Started Processing: Range(4170, 4179)
# Finished Processing: Range(4170, 4179)
# Started Processing: Range(4180, 4189)
# Finished Processing: Range(4180, 4189)
# Started Processing: Range(4190, 4199)
# Finished Processing: Range(4190, 4199)
# Started Processing: Range(4200, 4209)
# Finished Processing: Range(4200, 4209)
# Started Processing: Range(4210, 4219)
# Finished Processing: Range(4210, 4219)
# Started Processing: Range(4220, 4229)
# Finished Processing: Range(4220, 4229)
# Started Processing: Range(4230, 4239)
# Finished Processing: Range(4230, 4239)
# Started Processing: Range(4240, 4249)
# Finished Processing: Range(4240, 4249)
# Started Processing: Range(4250, 4259)
# Finished Processing: Range(4250, 4259)
# Started Processing: Range(4260, 4269)
# Finished Processing: Range(4260, 4269)
# Started Processing: Range(4270, 4279)
# Finished Processing: Range(4270, 4279)
# Started Processing: Range(4280, 4289)
# Finished Processing: Range(4280, 4289)
# Started Processing: Range(4290, 4299)
# Finished Processing: Range(4290, 4299)
# Started Processing: Range(4300, 4309)
# Finished Processing: Range(4300, 4309)
# Started Processing: Range(4310, 4319)
# Finished Processing: Range(4310, 4319)
# Started Processing: Range(4320, 4329)
# Finished Processing: Range(4320, 4329)
# Started Processing: Range(4330, 4339)
# Finished Processing: Range(4330, 4339)
# Started Processing: Range(4340, 4349)
# Finished Processing: Range(4340, 4349)
# Started Processing: Range(4350, 4359)
# Finished Processing: Range(4350, 4359)
# Started Processing: Range(4360, 4369)
# Finished Processing: Range(4360, 4369)
# Started Processing: Range(4370, 4379)
# Finished Processing: Range(4370, 4379)
# Started Processing: Range(4380, 4389)
# Finished Processing: Range(4380, 4389)
# Started Processing: Range(4390, 4399)
# Finished Processing: Range(4390, 4399)
# Started Processing: Range(4400, 4409)
# Finished Processing: Range(4400, 4409)
# Started Processing: Range(4410, 4419)
# Finished Processing: Range(4410, 4419)
# Started Processing: Range(4420, 4429)
# Finished Processing: Range(4420, 4429)
# Started Processing: Range(4430, 4439)
# Finished Processing: Range(4430, 4439)
# Started Processing: Range(4440, 4449)
# Finished Processing: Range(4440, 4449)
# Started Processing: Range(4450, 4459)
# Finished Processing: Range(4450, 4459)
# Started Processing: Range(4460, 4469)
# Finished Processing: Range(4460, 4469)
# Started Processing: Range(4470, 4479)
# Finished Processing: Range(4470, 4479)
# Started Processing: Range(4480, 4489)
# Finished Processing: Range(4480, 4489)
# Started Processing: Range(4490, 4499)
# Finished Processing: Range(4490, 4499)
# Started Processing: Range(4500, 4509)
# Finished Processing: Range(4500, 4509)
# Started Processing: Range(4510, 4519)
# Finished Processing: Range(4510, 4519)
# Started Processing: Range(4520, 4529)
# Finished Processing: Range(4520, 4529)
# Started Processing: Range(4530, 4539)
# Finished Processing: Range(4530, 4539)
# Started Processing: Range(4540, 4549)
# Finished Processing: Range(4540, 4549)
# Started Processing: Range(4550, 4559)
# Finished Processing: Range(4550, 4559)
# Started Processing: Range(4560, 4569)
# Finished Processing: Range(4560, 4569)
# Started Processing: Range(4570, 4579)
# Finished Processing: Range(4570, 4579)
# Started Processing: Range(4580, 4589)
# Finished Processing: Range(4580, 4589)
# Started Processing: Range(4590, 4599)
# Finished Processing: Range(4590, 4599)
# Started Processing: Range(4600, 4609)
# Finished Processing: Range(4600, 4609)
# Started Processing: Range(4610, 4619)
# Finished Processing: Range(4610, 4619)
# Started Processing: Range(4620, 4629)
# Finished Processing: Range(4620, 4629)
# Started Processing: Range(4630, 4639)
# Finished Processing: Range(4630, 4639)
# Started Processing: Range(4640, 4649)
# Finished Processing: Range(4640, 4649)
# Started Processing: Range(4650, 4659)
# Finished Processing: Range(4650, 4659)
# Started Processing: Range(4660, 4669)
# Finished Processing: Range(4660, 4669)
# Started Processing: Range(4670, 4679)
# Finished Processing: Range(4670, 4679)
# Started Processing: Range(4680, 4689)
# Finished Processing: Range(4680, 4689)
# Started Processing: Range(4690, 4699)
# Finished Processing: Range(4690, 4699)
# Started Processing: Range(4700, 4709)
# Finished Processing: Range(4700, 4709)
# Started Processing: Range(4710, 4719)
# Finished Processing: Range(4710, 4719)
# Started Processing: Range(4720, 4729)
# Finished Processing: Range(4720, 4729)
# Started Processing: Range(4730, 4739)
# Finished Processing: Range(4730, 4739)
# Started Processing: Range(4740, 4749)
# Finished Processing: Range(4740, 4749)
# Started Processing: Range(4750, 4759)
# Finished Processing: Range(4750, 4759)
# Started Processing: Range(4760, 4769)
# Finished Processing: Range(4760, 4769)
# Started Processing: Range(4770, 4779)
# Finished Processing: Range(4770, 4779)
# Started Processing: Range(4780, 4789)
# Finished Processing: Range(4780, 4789)
# Started Processing: Range(4790, 4799)
# Finished Processing: Range(4790, 4799)
# Started Processing: Range(4800, 4809)
# Finished Processing: Range(4800, 4809)
# Started Processing: Range(4810, 4819)
# Finished Processing: Range(4810, 4819)
# Started Processing: Range(4820, 4829)
# Finished Processing: Range(4820, 4829)
# Started Processing: Range(4830, 4839)
# Finished Processing: Range(4830, 4839)
# Started Processing: Range(4840, 4849)
# Finished Processing: Range(4840, 4849)
# Started Processing: Range(4850, 4859)
# Finished Processing: Range(4850, 4859)
# Started Processing: Range(4860, 4869)
# Finished Processing: Range(4860, 4869)
# Started Processing: Range(4870, 4879)
# Finished Processing: Range(4870, 4879)
# Started Processing: Range(4880, 4889)
# Finished Processing: Range(4880, 4889)
# Started Processing: Range(4890, 4899)
# Finished Processing: Range(4890, 4899)
# Started Processing: Range(4900, 4909)
# Finished Processing: Range(4900, 4909)
# Started Processing: Range(4910, 4919)
# Finished Processing: Range(4910, 4919)
# Started Processing: Range(4920, 4929)
# Finished Processing: Range(4920, 4929)
# Started Processing: Range(4930, 4939)
# Finished Processing: Range(4930, 4939)
# Started Processing: Range(4940, 4949)
# Finished Processing: Range(4940, 4949)
# Started Processing: Range(4950, 4959)
# Finished Processing: Range(4950, 4959)
# Started Processing: Range(4960, 4969)
# Finished Processing: Range(4960, 4969)
# Started Processing: Range(4970, 4979)
# Finished Processing: Range(4970, 4979)
# Started Processing: Range(4980, 4989)
# Finished Processing: Range(4980, 4989)
# Started Processing: Range(4990, 4999)
# Finished Processing: Range(4990, 4999)
# Started Processing: Range(5000, 5009)
# Finished Processing: Range(5000, 5009)
# Started Processing: Range(5010, 5019)
# Finished Processing: Range(5010, 5019)
# Started Processing: Range(5020, 5029)
# Finished Processing: Range(5020, 5029)
# Started Processing: Range(5030, 5039)
# Finished Processing: Range(5030, 5039)
# Started Processing: Range(5040, 5049)
# Finished Processing: Range(5040, 5049)
# Started Processing: Range(5050, 5059)
# Finished Processing: Range(5050, 5059)
# Started Processing: Range(5060, 5069)
# Finished Processing: Range(5060, 5069)
# Started Processing: Range(5070, 5079)
# Finished Processing: Range(5070, 5079)
# Started Processing: Range(5080, 5089)
# Finished Processing: Range(5080, 5089)
# Started Processing: Range(5090, 5099)
# Finished Processing: Range(5090, 5099)
# Started Processing: Range(5100, 5109)
# Finished Processing: Range(5100, 5109)
# Started Processing: Range(5110, 5119)
# Finished Processing: Range(5110, 5119)
# Started Processing: Range(5120, 5129)
# Finished Processing: Range(5120, 5129)
# Started Processing: Range(5130, 5139)
# Finished Processing: Range(5130, 5139)
# Started Processing: Range(5140, 5149)
# Finished Processing: Range(5140, 5149)
# Started Processing: Range(5150, 5159)
# Finished Processing: Range(5150, 5159)
# Started Processing: Range(5160, 5169)
# Finished Processing: Range(5160, 5169)
# Started Processing: Range(5170, 5179)
# Finished Processing: Range(5170, 5179)
# Started Processing: Range(5180, 5189)
# Finished Processing: Range(5180, 5189)
# Started Processing: Range(5190, 5199)
# Finished Processing: Range(5190, 5199)
# Started Processing: Range(5200, 5209)
# Finished Processing: Range(5200, 5209)
# Started Processing: Range(5210, 5219)
# Finished Processing: Range(5210, 5219)
# Started Processing: Range(5220, 5229)
# Finished Processing: Range(5220, 5229)
# Started Processing: Range(5230, 5239)
# Finished Processing: Range(5230, 5239)
# Started Processing: Range(5240, 5249)
# Finished Processing: Range(5240, 5249)
# Started Processing: Range(5250, 5259)
# Finished Processing: Range(5250, 5259)
# Started Processing: Range(5260, 5269)
# Finished Processing: Range(5260, 5269)
# Started Processing: Range(5270, 5279)
# Finished Processing: Range(5270, 5279)
# Started Processing: Range(5280, 5289)
# Finished Processing: Range(5280, 5289)
# Started Processing: Range(5290, 5299)
# Finished Processing: Range(5290, 5299)
# Started Processing: Range(5300, 5309)
# Finished Processing: Range(5300, 5309)
# Started Processing: Range(5310, 5319)
# Finished Processing: Range(5310, 5319)
# Started Processing: Range(5320, 5329)
# Finished Processing: Range(5320, 5329)
# Started Processing: Range(5330, 5339)
# Finished Processing: Range(5330, 5339)
# Started Processing: Range(5340, 5349)
# Finished Processing: Range(5340, 5349)
# Started Processing: Range(5350, 5359)
# Finished Processing: Range(5350, 5359)
# Started Processing: Range(5360, 5369)
# Finished Processing: Range(5360, 5369)
# Started Processing: Range(5370, 5379)
# Finished Processing: Range(5370, 5379)
# Started Processing: Range(5380, 5389)
# Finished Processing: Range(5380, 5389)
# Started Processing: Range(5390, 5399)
# Finished Processing: Range(5390, 5399)
# Started Processing: Range(5400, 5409)
# Finished Processing: Range(5400, 5409)
# Started Processing: Range(5410, 5419)
# Finished Processing: Range(5410, 5419)
# Started Processing: Range(5420, 5429)
# Finished Processing: Range(5420, 5429)
# Started Processing: Range(5430, 5439)
# Finished Processing: Range(5430, 5439)
# Started Processing: Range(5440, 5449)
# Finished Processing: Range(5440, 5449)
# Started Processing: Range(5450, 5459)
# Finished Processing: Range(5450, 5459)
# Started Processing: Range(5460, 5469)
# Finished Processing: Range(5460, 5469)
# Started Processing: Range(5470, 5479)
# Finished Processing: Range(5470, 5479)
# Started Processing: Range(5480, 5489)
# Finished Processing: Range(5480, 5489)
# Started Processing: Range(5490, 5499)
# Finished Processing: Range(5490, 5499)
# Started Processing: Range(5500, 5509)
# Finished Processing: Range(5500, 5509)
# Started Processing: Range(5510, 5519)
# Finished Processing: Range(5510, 5519)
# Started Processing: Range(5520, 5529)
# Finished Processing: Range(5520, 5529)
# Started Processing: Range(5530, 5539)
# Finished Processing: Range(5530, 5539)
# Started Processing: Range(5540, 5549)
# Finished Processing: Range(5540, 5549)
# Started Processing: Range(5550, 5559)
# Finished Processing: Range(5550, 5559)
# Started Processing: Range(5560, 5569)
# Finished Processing: Range(5560, 5569)
# Started Processing: Range(5570, 5579)
# Finished Processing: Range(5570, 5579)
# Started Processing: Range(5580, 5589)
# Finished Processing: Range(5580, 5589)
# Started Processing: Range(5590, 5599)
# Finished Processing: Range(5590, 5599)
# Started Processing: Range(5600, 5609)
# Finished Processing: Range(5600, 5609)
# Started Processing: Range(5610, 5619)
# Finished Processing: Range(5610, 5619)
# Started Processing: Range(5620, 5629)
# Finished Processing: Range(5620, 5629)
# Started Processing: Range(5630, 5639)
# Finished Processing: Range(5630, 5639)
# Started Processing: Range(5640, 5649)
# Finished Processing: Range(5640, 5649)
# Started Processing: Range(5650, 5659)
# Finished Processing: Range(5650, 5659)
# Started Processing: Range(5660, 5669)
# Finished Processing: Range(5660, 5669)
# Started Processing: Range(5670, 5679)
# Finished Processing: Range(5670, 5679)
# Started Processing: Range(5680, 5689)
# Finished Processing: Range(5680, 5689)
# Started Processing: Range(5690, 5699)
# Finished Processing: Range(5690, 5699)
# Started Processing: Range(5700, 5709)
# Finished Processing: Range(5700, 5709)
# Started Processing: Range(5710, 5719)
# Finished Processing: Range(5710, 5719)
# Started Processing: Range(5720, 5729)
# Finished Processing: Range(5720, 5729)
# Started Processing: Range(5730, 5739)
# Finished Processing: Range(5730, 5739)
# Started Processing: Range(5740, 5749)
# Finished Processing: Range(5740, 5749)
# Started Processing: Range(5750, 5759)
# Finished Processing: Range(5750, 5759)
# Started Processing: Range(5760, 5769)
# Finished Processing: Range(5760, 5769)
# Started Processing: Range(5770, 5779)
# Finished Processing: Range(5770, 5779)
# Started Processing: Range(5780, 5789)
# Finished Processing: Range(5780, 5789)
# Started Processing: Range(5790, 5799)
# Finished Processing: Range(5790, 5799)
# Started Processing: Range(5800, 5809)
# Finished Processing: Range(5800, 5809)
# Started Processing: Range(5810, 5819)
# Finished Processing: Range(5810, 5819)
# Started Processing: Range(5820, 5829)
# Finished Processing: Range(5820, 5829)
# Started Processing: Range(5830, 5839)
# Finished Processing: Range(5830, 5839)
# Started Processing: Range(5840, 5849)
# Finished Processing: Range(5840, 5849)
# Started Processing: Range(5850, 5859)
# Finished Processing: Range(5850, 5859)
# Started Processing: Range(5860, 5869)
# Finished Processing: Range(5860, 5869)
# Started Processing: Range(5870, 5879)
# Finished Processing: Range(5870, 5879)
# Started Processing: Range(5880, 5889)
# Finished Processing: Range(5880, 5889)
# Started Processing: Range(5890, 5899)
# Finished Processing: Range(5890, 5899)
# Started Processing: Range(5900, 5909)
# Finished Processing: Range(5900, 5909)
# Started Processing: Range(5910, 5919)
# Finished Processing: Range(5910, 5919)
# Started Processing: Range(5920, 5929)
# Finished Processing: Range(5920, 5929)
# Started Processing: Range(5930, 5939)
# Finished Processing: Range(5930, 5939)
# Started Processing: Range(5940, 5949)
# Finished Processing: Range(5940, 5949)
# Started Processing: Range(5950, 5959)
# Finished Processing: Range(5950, 5959)
# Started Processing: Range(5960, 5969)
# Finished Processing: Range(5960, 5969)
# Started Processing: Range(5970, 5979)
# Finished Processing: Range(5970, 5979)
# Started Processing: Range(5980, 5989)
# Finished Processing: Range(5980, 5989)
# Started Processing: Range(5990, 5999)
# Finished Processing: Range(5990, 5999)
# Started Processing: Range(6000, 6009)
# Finished Processing: Range(6000, 6009)
# Started Processing: Range(6010, 6019)
# Finished Processing: Range(6010, 6019)
# Started Processing: Range(6020, 6029)
# Finished Processing: Range(6020, 6029)
# Started Processing: Range(6030, 6039)
# Finished Processing: Range(6030, 6039)
# Started Processing: Range(6040, 6049)
# Finished Processing: Range(6040, 6049)
# Started Processing: Range(6050, 6059)
# Finished Processing: Range(6050, 6059)
# Started Processing: Range(6060, 6069)
# Finished Processing: Range(6060, 6069)
# Started Processing: Range(6070, 6079)
# Finished Processing: Range(6070, 6079)
# Started Processing: Range(6080, 6089)
# Finished Processing: Range(6080, 6089)
# Started Processing: Range(6090, 6099)
# Finished Processing: Range(6090, 6099)
# Started Processing: Range(6100, 6109)
# Finished Processing: Range(6100, 6109)
# Started Processing: Range(6110, 6119)
# Finished Processing: Range(6110, 6119)
# Started Processing: Range(6120, 6129)
# Finished Processing: Range(6120, 6129)
# Started Processing: Range(6130, 6139)
# Finished Processing: Range(6130, 6139)
# Started Processing: Range(6140, 6149)
# Finished Processing: Range(6140, 6149)
# Started Processing: Range(6150, 6159)
# Finished Processing: Range(6150, 6159)
# Started Processing: Range(6160, 6169)
# Finished Processing: Range(6160, 6169)
# Started Processing: Range(6170, 6179)
# Finished Processing: Range(6170, 6179)
# Started Processing: Range(6180, 6189)
# Finished Processing: Range(6180, 6189)
# Started Processing: Range(6190, 6199)
# Finished Processing: Range(6190, 6199)
# Started Processing: Range(6200, 6209)
# Finished Processing: Range(6200, 6209)
# Started Processing: Range(6210, 6219)
# Finished Processing: Range(6210, 6219)
# Started Processing: Range(6220, 6229)
# Finished Processing: Range(6220, 6229)
# Started Processing: Range(6230, 6239)
# Finished Processing: Range(6230, 6239)
# Started Processing: Range(6240, 6249)
# Finished Processing: Range(6240, 6249)
# Started Processing: Range(6250, 6259)
# Finished Processing: Range(6250, 6259)
# Started Processing: Range(6260, 6269)
# Finished Processing: Range(6260, 6269)
# Started Processing: Range(6270, 6279)
# Finished Processing: Range(6270, 6279)
# Started Processing: Range(6280, 6289)
# Finished Processing: Range(6280, 6289)
# ...
# Started Processing: Range(13120, 13129)
# Finished Processing: Range(13120, 13129)
# Started Processing: Range(13130, 13139)
# Finished Processing: Range(13130, 13139)
# Started Processing: Range(13140, 13149)
# Finished Processing: Range(13140, 13149)
# Started Processing: Range(13150, 13159)
# Finished Processing: Range(13150, 13159)
# Started Processing: Range(13160, 13169)
# Finished Processing: Range(13160, 13169)
# Started Processing: Range(13170, 13179)
# Finished Processing: Range(13170, 13179)
# Started Processing: Range(13180, 13189)
# Finished Processing: Range(13180, 13189)
# Started Processing: Range(13190, 13199)
# Finished Processing: Range(13190, 13199)
# Started Processing: Range(13200, 13209)
# Finished Processing: Range(13200, 13209)
# Started Processing: Range(13210, 13219)
# Finished Processing: Range(13210, 13219)
# Started Processing: Range(13220, 13229)
# Finished Processing: Range(13220, 13229)
# Started Processing: Range(13230, 13239)
# Finished Processing: Range(13230, 13239)
# Started Processing: Range(13240, 13249)
# Finished Processing: Range(13240, 13249)
# Started Processing: Range(13250, 13259)
# Finished Processing: Range(13250, 13259)
# Started Processing: Range(13260, 13269)
# Finished Processing: Range(13260, 13269)
# Started Processing: Range(13270, 13279)
# Finished Processing: Range(13270, 13279)
# Started Processing: Range(13280, 13289)
# Finished Processing: Range(13280, 13289)
# Started Processing: Range(13290, 13299)
# Finished Processing: Range(13290, 13299)
# Started Processing: Range(13300, 13309)
# Finished Processing: Range(13300, 13309)
# Started Processing: Range(13310, 13319)
# Finished Processing: Range(13310, 13319)
# Started Processing: Range(13320, 13329)
# Finished Processing: Range(13320, 13329)
# Started Processing: Range(13330, 13339)
# Finished Processing: Range(13330, 13339)
# Started Processing: Range(13340, 13349)
# Finished Processing: Range(13340, 13349)
# Started Processing: Range(13350, 13359)
# Finished Processing: Range(13350, 13359)
# Started Processing: Range(13360, 13369)
# Finished Processing: Range(13360, 13369)
# Started Processing: Range(13370, 13379)
# Finished Processing: Range(13370, 13379)
# Started Processing: Range(13380, 13389)
# Finished Processing: Range(13380, 13389)
# Started Processing: Range(13390, 13399)
# Finished Processing: Range(13390, 13399)
# Started Processing: Range(13400, 13409)
# Finished Processing: Range(13400, 13409)
# Started Processing: Range(13410, 13419)
# Finished Processing: Range(13410, 13419)
# Started Processing: Range(13420, 13429)
# Finished Processing: Range(13420, 13429)
# Started Processing: Range(13430, 13439)
# Finished Processing: Range(13430, 13439)
# Started Processing: Range(13440, 13449)
# Finished Processing: Range(13440, 13449)
# Started Processing: Range(13450, 13459)
# Finished Processing: Range(13450, 13459)
# Started Processing: Range(13460, 13469)
# Finished Processing: Range(13460, 13469)
# Started Processing: Range(13470, 13479)
# Finished Processing: Range(13470, 13479)
# Started Processing: Range(13480, 13489)
# Finished Processing: Range(13480, 13489)
# Started Processing: Range(13490, 13499)
# Finished Processing: Range(13490, 13499)
# Started Processing: Range(13500, 13509)
# Finished Processing: Range(13500, 13509)
# Started Processing: Range(13510, 13519)
# Finished Processing: Range(13510, 13519)
# Started Processing: Range(13520, 13529)
# Finished Processing: Range(13520, 13529)
# Started Processing: Range(13530, 13539)
# Finished Processing: Range(13530, 13539)
# Started Processing: Range(13540, 13549)
# Finished Processing: Range(13540, 13549)
# Started Processing: Range(13550, 13559)
# Finished Processing: Range(13550, 13559)
# Started Processing: Range(13560, 13569)
# Finished Processing: Range(13560, 13569)
# Started Processing: Range(13570, 13579)
# Finished Processing: Range(13570, 13579)
# Started Processing: Range(13580, 13589)
# Finished Processing: Range(13580, 13589)
# Started Processing: Range(13590, 13599)
# Finished Processing: Range(13590, 13599)
# Started Processing: Range(13600, 13609)
# Finished Processing: Range(13600, 13609)
# Started Processing: Range(13610, 13619)
# Finished Processing: Range(13610, 13619)
# Started Processing: Range(13620, 13629)
# Finished Processing: Range(13620, 13629)
# Started Processing: Range(13630, 13639)
# Finished Processing: Range(13630, 13639)
# Started Processing: Range(13640, 13649)
# Finished Processing: Range(13640, 13649)
# Started Processing: Range(13650, 13659)
# Finished Processing: Range(13650, 13659)
# Started Processing: Range(13660, 13669)
# Finished Processing: Range(13660, 13669)
# Started Processing: Range(13670, 13679)
# Finished Processing: Range(13670, 13679)
# Started Processing: Range(13680, 13689)
# Finished Processing: Range(13680, 13689)
# Started Processing: Range(13690, 13699)
# Finished Processing: Range(13690, 13699)
# Started Processing: Range(13700, 13709)
# Finished Processing: Range(13700, 13709)
# Started Processing: Range(13710, 13719)
# Finished Processing: Range(13710, 13719)
# Started Processing: Range(13720, 13729)
# Finished Processing: Range(13720, 13729)
# Started Processing: Range(13730, 13739)
# Finished Processing: Range(13730, 13739)
# Started Processing: Range(13740, 13749)
# Finished Processing: Range(13740, 13749)
# Started Processing: Range(13750, 13759)
# Finished Processing: Range(13750, 13759)
# Started Processing: Range(13760, 13769)
# Finished Processing: Range(13760, 13769)
# Started Processing: Range(13770, 13779)
# Finished Processing: Range(13770, 13779)
# Started Processing: Range(13780, 13789)
# Finished Processing: Range(13780, 13789)
# Started Processing: Range(13790, 13799)
# Finished Processing: Range(13790, 13799)
# Started Processing: Range(13800, 13809)
# Finished Processing: Range(13800, 13809)
# Started Processing: Range(13810, 13819)
# Finished Processing: Range(13810, 13819)
# Started Processing: Range(13820, 13829)
# Finished Processing: Range(13820, 13829)
# Started Processing: Range(13830, 13839)
# Finished Processing: Range(13830, 13839)
# Started Processing: Range(13840, 13849)
# Finished Processing: Range(13840, 13849)
# Started Processing: Range(13850, 13859)
# Finished Processing: Range(13850, 13859)
# Started Processing: Range(13860, 13869)
# Finished Processing: Range(13860, 13869)
# Started Processing: Range(13870, 13879)
# Finished Processing: Range(13870, 13879)
# Started Processing: Range(13880, 13889)
# Finished Processing: Range(13880, 13889)
# Started Processing: Range(13890, 13899)
# Finished Processing: Range(13890, 13899)
# Started Processing: Range(13900, 13909)
# Finished Processing: Range(13900, 13909)
# Started Processing: Range(13910, 13919)
# Finished Processing: Range(13910, 13919)
# Started Processing: Range(13920, 13929)
# Finished Processing: Range(13920, 13929)
# Started Processing: Range(13930, 13939)
# Finished Processing: Range(13930, 13939)
# Started Processing: Range(13940, 13949)
# Finished Processing: Range(13940, 13949)
# Started Processing: Range(13950, 13959)
# Finished Processing: Range(13950, 13959)
# Started Processing: Range(13960, 13969)
# Finished Processing: Range(13960, 13969)
# Started Processing: Range(13970, 13979)
# Finished Processing: Range(13970, 13979)
# Started Processing: Range(13980, 13989)
# Finished Processing: Range(13980, 13989)
# Started Processing: Range(13990, 13999)
# Finished Processing: Range(13990, 13999)
# Started Processing: Range(14000, 14009)
# Finished Processing: Range(14000, 14009)
# Started Processing: Range(14010, 14019)
# Finished Processing: Range(14010, 14019)
# Started Processing: Range(14020, 14029)
# Finished Processing: Range(14020, 14029)
# Started Processing: Range(14030, 14039)
# Finished Processing: Range(14030, 14039)
# Started Processing: Range(14040, 14049)
# Finished Processing: Range(14040, 14049)
# Started Processing: Range(14050, 14059)
# Finished Processing: Range(14050, 14059)
# Started Processing: Range(14060, 14069)
# Finished Processing: Range(14060, 14069)
# Started Processing: Range(14070, 14079)
# Finished Processing: Range(14070, 14079)
# Started Processing: Range(14080, 14089)
# Finished Processing: Range(14080, 14089)
# Started Processing: Range(14090, 14099)
# Finished Processing: Range(14090, 14099)
# Started Processing: Range(14100, 14109)
# Finished Processing: Range(14100, 14109)
# Started Processing: Range(14110, 14119)
# Finished Processing: Range(14110, 14119)
# Started Processing: Range(14120, 14129)
# Finished Processing: Range(14120, 14129)
# Started Processing: Range(14130, 14139)
# Finished Processing: Range(14130, 14139)
# Started Processing: Range(14140, 14149)
# Finished Processing: Range(14140, 14149)
# Started Processing: Range(14150, 14159)
# Finished Processing: Range(14150, 14159)
# Started Processing: Range(14160, 14169)
# Finished Processing: Range(14160, 14169)
# Started Processing: Range(14170, 14179)
# Finished Processing: Range(14170, 14179)
# Started Processing: Range(14180, 14189)
# Finished Processing: Range(14180, 14189)
# Started Processing: Range(14190, 14199)
# Finished Processing: Range(14190, 14199)
# Started Processing: Range(14200, 14209)
# Finished Processing: Range(14200, 14209)
# Started Processing: Range(14210, 14219)
# Finished Processing: Range(14210, 14219)
# Started Processing: Range(14220, 14229)
# Finished Processing: Range(14220, 14229)
# Started Processing: Range(14230, 14239)
# Finished Processing: Range(14230, 14239)
# Started Processing: Range(14240, 14249)
# Finished Processing: Range(14240, 14249)
# Started Processing: Range(14250, 14259)
# Finished Processing: Range(14250, 14259)
# Started Processing: Range(14260, 14269)
# Finished Processing: Range(14260, 14269)
# Started Processing: Range(14270, 14279)
# Finished Processing: Range(14270, 14279)
# Started Processing: Range(14280, 14289)
# Finished Processing: Range(14280, 14289)
# Started Processing: Range(14290, 14299)
# Finished Processing: Range(14290, 14299)
# Started Processing: Range(14300, 14309)
# Finished Processing: Range(14300, 14309)
# Started Processing: Range(14310, 14319)
# Finished Processing: Range(14310, 14319)
# Started Processing: Range(14320, 14329)
# Finished Processing: Range(14320, 14329)
# Started Processing: Range(14330, 14339)
# Finished Processing: Range(14330, 14339)
# Started Processing: Range(14340, 14349)
# Finished Processing: Range(14340, 14349)
# Started Processing: Range(14350, 14359)
# Finished Processing: Range(14350, 14359)
# Started Processing: Range(14360, 14369)
# Finished Processing: Range(14360, 14369)
# Started Processing: Range(14370, 14379)
# Finished Processing: Range(14370, 14379)
# Started Processing: Range(14380, 14389)
# Finished Processing: Range(14380, 14389)
# Started Processing: Range(14390, 14399)
# Finished Processing: Range(14390, 14399)
# Started Processing: Range(14400, 14409)
# Finished Processing: Range(14400, 14409)
# Started Processing: Range(14410, 14419)
# Finished Processing: Range(14410, 14419)
# Started Processing: Range(14420, 14429)
# Finished Processing: Range(14420, 14429)
# Started Processing: Range(14430, 14439)
# Finished Processing: Range(14430, 14439)
# Started Processing: Range(14440, 14449)
# Finished Processing: Range(14440, 14449)
# Started Processing: Range(14450, 14459)
# Finished Processing: Range(14450, 14459)
# Started Processing: Range(14460, 14469)
# Finished Processing: Range(14460, 14469)
# Started Processing: Range(14470, 14479)
# Finished Processing: Range(14470, 14479)
# Started Processing: Range(14480, 14489)
# Finished Processing: Range(14480, 14489)
# Started Processing: Range(14490, 14499)
# Finished Processing: Range(14490, 14499)
# Started Processing: Range(14500, 14509)
# Finished Processing: Range(14500, 14509)
# Started Processing: Range(14510, 14519)
# Finished Processing: Range(14510, 14519)
# Started Processing: Range(14520, 14529)
# Finished Processing: Range(14520, 14529)
# Started Processing: Range(14530, 14539)
# Finished Processing: Range(14530, 14539)
# Started Processing: Range(14540, 14549)
# Finished Processing: Range(14540, 14549)
# Started Processing: Range(14550, 14559)
# Finished Processing: Range(14550, 14559)
# Started Processing: Range(14560, 14569)
# Finished Processing: Range(14560, 14569)
# Started Processing: Range(14570, 14579)
# Finished Processing: Range(14570, 14579)
# Started Processing: Range(14580, 14589)
# Finished Processing: Range(14580, 14589)
# Started Processing: Range(14590, 14599)
# Finished Processing: Range(14590, 14599)
# Started Processing: Range(14600, 14609)
# Finished Processing: Range(14600, 14609)
# Started Processing: Range(14610, 14619)
# Finished Processing: Range(14610, 14619)
# Started Processing: Range(14620, 14629)
# Finished Processing: Range(14620, 14629)
# Started Processing: Range(14630, 14639)
# Finished Processing: Range(14630, 14639)
# Started Processing: Range(14640, 14649)
# Finished Processing: Range(14640, 14649)
# Started Processing: Range(14650, 14659)
# Finished Processing: Range(14650, 14659)
# Started Processing: Range(14660, 14669)
# Finished Processing: Range(14660, 14669)
# Started Processing: Range(14670, 14679)
# Finished Processing: Range(14670, 14679)
# Started Processing: Range(14680, 14689)
# Finished Processing: Range(14680, 14689)
# Started Processing: Range(14690, 14699)
# Finished Processing: Range(14690, 14699)
# Started Processing: Range(14700, 14709)
# Finished Processing: Range(14700, 14709)
# Started Processing: Range(14710, 14719)
# Finished Processing: Range(14710, 14719)
# Started Processing: Range(14720, 14729)
# Finished Processing: Range(14720, 14729)
# Started Processing: Range(14730, 14739)
# Finished Processing: Range(14730, 14739)
# Started Processing: Range(14740, 14749)
# Finished Processing: Range(14740, 14749)
# Started Processing: Range(14750, 14759)
# Finished Processing: Range(14750, 14759)
# Started Processing: Range(14760, 14769)
# Finished Processing: Range(14760, 14769)
# Started Processing: Range(14770, 14779)
# Finished Processing: Range(14770, 14779)
# Started Processing: Range(14780, 14789)
# Finished Processing: Range(14780, 14789)
# Started Processing: Range(14790, 14799)
# Finished Processing: Range(14790, 14799)
# Started Processing: Range(14800, 14809)
# Finished Processing: Range(14800, 14809)
# Started Processing: Range(14810, 14819)
# Finished Processing: Range(14810, 14819)
# Started Processing: Range(14820, 14829)
# Finished Processing: Range(14820, 14829)
# Started Processing: Range(14830, 14839)
# Finished Processing: Range(14830, 14839)
# Started Processing: Range(14840, 14849)
# Finished Processing: Range(14840, 14849)
# Started Processing: Range(14850, 14859)
# Finished Processing: Range(14850, 14859)
# Started Processing: Range(14860, 14869)
# Finished Processing: Range(14860, 14869)
# Started Processing: Range(14870, 14879)
# Finished Processing: Range(14870, 14879)
# Started Processing: Range(14880, 14889)
# Finished Processing: Range(14880, 14889)
# Started Processing: Range(14890, 14899)
# Finished Processing: Range(14890, 14899)
# Started Processing: Range(14900, 14909)
# Finished Processing: Range(14900, 14909)
# Started Processing: Range(14910, 14919)
# Finished Processing: Range(14910, 14919)
# Started Processing: Range(14920, 14929)
# Finished Processing: Range(14920, 14929)
# Started Processing: Range(14930, 14939)
# Finished Processing: Range(14930, 14939)
# Started Processing: Range(14940, 14949)
# Finished Processing: Range(14940, 14949)
# Started Processing: Range(14950, 14959)
# Finished Processing: Range(14950, 14959)
# Started Processing: Range(14960, 14969)
# Finished Processing: Range(14960, 14969)
# Started Processing: Range(14970, 14979)
# Finished Processing: Range(14970, 14979)
# Started Processing: Range(14980, 14989)
# Finished Processing: Range(14980, 14989)
# Started Processing: Range(14990, 14999)
# Finished Processing: Range(14990, 14999)
# Started Processing: Range(15000, 15009)
# Finished Processing: Range(15000, 15009)
# Started Processing: Range(15010, 15019)
# Finished Processing: Range(15010, 15019)
# Started Processing: Range(15020, 15029)
# Finished Processing: Range(15020, 15029)
# Started Processing: Range(15030, 15039)
# Finished Processing: Range(15030, 15039)
# Started Processing: Range(15040, 15049)
# Finished Processing: Range(15040, 15049)
# Started Processing: Range(15050, 15059)
# Finished Processing: Range(15050, 15059)
# Started Processing: Range(15060, 15069)
# Finished Processing: Range(15060, 15069)
# Started Processing: Range(15070, 15079)
# Finished Processing: Range(15070, 15079)
# Started Processing: Range(15080, 15089)
# SOME ERROR OCCURRED...PASSING!!!
# 'the label [15087] is not in the [index]'

# %%
filter_df = new_tweet_df_english["nlp_key_phrases"] != ""
tweets_with_nlp = new_tweet_df_english[filter_df]

tweets_with_nlp.shape
# Out:
# (14801, 30)

# %%
#Save tweets with NLP to .json file
new_tweet_json = tweets_with_nlp.to_json(orient='records')

with open('more_final_tweets_master_withNLP.json', 'w') as outfile:  
    json.dump(new_tweet_json , outfile)

# %%
#Check tweets with NLP to .json file

with open('more_final_tweets_master_withNLP.json') as json_file:  
    tweet_json = json.load(json_file)
    
tweets_with_nlp_reload = pd.read_json(tweet_json)

tweets_with_nlp_reload.shape
# Out:
# (14801, 30)

# %%
#Show some examples of tweets with NLP features
tweets_with_nlp_reload.loc[1:5][["nlp_key_phrases", "nlp_count_key_phrases", "nlp_sentiment_score", "text"]]
# Out:
#                                      nlp_key_phrases  nlp_count_key_phrases  \
# 1                                       TheLieIsMilk                      1
# 2              Verizon,Vote,truth,word,TheLieIsPoker                      5
# 3         Obama,times,family fly,Hawaii,KaivanShroff                      5
# 4  ISIS,RT,JackPosobiec,roof,babbl,Illegal immigr...                      6
# 5    thing,New England game,HoustonTexans,big losses                      4
#
#    nlp_sentiment_score                                               text
# 1             0.810814  I say #TheLieIsMilk. Something just doesn’t fe...
# 2             0.879872  Don’t take my word for it, but I think #TheLie...
# 3             0.500000  @KaivanShroff How many times did Obama and his...
# 4             0.039690  RT @JackPosobiec: ISIS is decimated in 11 mont...
# 5             0.218688  @HoustonTexans Same thing in the New England g...
